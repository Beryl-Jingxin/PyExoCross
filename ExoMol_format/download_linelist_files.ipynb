# %% [markdown]
# ## Import all what we need

# %%
import os
import sys
import json
import urllib3
import requests
import subprocess
from tqdm.notebook import tqdm
urllib3.disable_warnings()

# %% [markdown]
# ## File Paths
#
#
# <table><tr><td bgcolor=skyblue><font size=24> Could be changed ! </font></td></tr></table>

# %%
#########################################################
def_path = '/home/jingxin/data/test/def'
url_path = '/home/jingxin/data/pyexocross/url'
molecule = ['MgH','NO']
iso_slug = ['24Mg-1H','14N-16O']
iso_formula = ['(24Mg)(1H)','(14N)(16O)']
dataset = ['XAB','XABC']
#########################################################

# %% [markdown]
# # Read Def File
#
# Get all URLs of def files. The number of def files should be the same as the number of isotopologue datasets. The URLs contains the names of molecules, iso-slugs and isotopologue datasets. We save their corresponding isoFormula names as another column.

# %%
def read_deffile(molecule, iso_slug, dataset):
    def_url = []
    def_num = len(iso_slug)
    for i in tqdm(range(def_num)):
        url = ('http://www.exomol.com/db/' + molecule[i] + '/'
               + iso_slug[i] + '/'+ dataset[i] + '/'
               + iso_slug[i] + '__' + dataset[i] + '.def')
        def_url.append(url)
    return(def_url)

# %% [markdown]
# Download def files and save them into ./data/def/ folder. Save the names of these def files with all information we got before, that is to say, save as 'molecule_isoFormula_iso-slug_isotopologue.def'. It will be more convenient for processing data later.

# %%
def download_deffile(def_path):
    failed_list = [] 
    def_url = read_deffile(molecule, iso_slug, dataset)
    for link in tqdm(def_url):
        def_filename = link.split('/')[-1]
        print("Downloading file: %s" % def_filename)
        print(link)
 
        # Make folders for save doanloaded files.
        if os.path.exists(def_path):
            pass
        else:
            os.makedirs(def_path, exist_ok=True)
        filename = os.path.join(def_path, def_filename)
        
        try:
            r = requests.get(link, stream=True, verify=False)
        except Exception:
            failed_list.append(def_filename)
            print(' download failed. Go to download next one\n')
              
        # For compute the progess.
        total_size = int(r.headers['Content-Length'])
        temp_size = 0    
   
        # Download started.
        with open(filename, 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024 * 1024):
                if chunk:
                    temp_size += len(chunk)
                    f.write(chunk)
                    f.flush()
                    done = int(50 * temp_size / total_size)
                    sys.stdout.write("\r[%s%s] %d%%" % ('█' * done, ' ' * (50 - done),
                                                        100 * temp_size / total_size))
                    sys.stdout.flush()
        print(" Downloaded!\n")
    print("All def files downloaded!\n")    
    print("The files which are failed to download: \n")
    print(failed_list) # Record which file is failed to download.

# %% [markdown]
# # Get Download Links with API
#
# Get the API URLs of those uncertainty molecules.

# %%
def get_api(def_path):
    molecule_str = []
    iso_str = []
    api_url = []
    for i in range(len(molecule)):
        molecule_str.append(molecule[i].replace('_p','+').split('__')[0].replace('+','_p'))
        iso_str.append(iso_slug[i].replace('_p','+'))
        api_url.append('http://exomol.com/api/?molecule=*&datatype=linelist'.replace('*',molecule_str[i]))
    return(api_url)

# %% [markdown]
# Get the download links of states.bz2 files and trans.bz2 files from API.

# %%
def get_target_url(def_path):
    """Get the download url from API."""
    file_url = []
    api_url = get_api(def_path)
    for i in range(len(molecule)):
        response = requests.get(api_url[i])
        if(response.status_code != 200):
            print('ExoMol API Error' + str(response.status_code))

        # If the obtained status code is 200, it is correct.
        else:
            content = response.text            # Get the relevant content.
            json_dict = json.loads(content)    # Convert json into dictionary.

            # Extract files information from dictionary and convert them into list
            _iso_formula = iso_formula[i]
            _dataset = dataset[i]
            json_list = json_dict[_iso_formula]['linelist'][_dataset]['files']
            onefile = "http://www." + json_list[0].get('url')
            def_pf = [onefile.replace('.states.bz2','.def'), onefile.replace('.states.bz2','.pf')]
            url_show = []
            for j in range(len(json_list)):
                link = json_list[j].get('url')
                try:
                    if((link.endswith('states.bz2') or link.endswith('trans.bz2'))):
                        print(link.split('/')[-1].replace('.states.bz2','.def'))
                        file_url.append("http://www." + link)
                        url_show.append("http://www." + link)
                except KeyError:
                    print('Keyerror, keep going!')
            file_url += def_pf
            url_show += def_pf
        print('\nThe number of downloading files for', _iso_formula, _dataset, ': ', len(url_show))
        print("Download links:")                    
        for k in url_show:
            print(k)
    return (file_url)

# %% [markdown]
# # Download States and Trans Files
#
# We write all the download URLs into a text file, name it as api__urls.txt.
#
# In Linux, we use command
#
# ```
# wget -d -r -i /.../save_path/.../api__urls.txt
# ```
#
# Download states.bz2 files and trans.bz2 files with download links. Save these files into correspoding folders.

# %%
def download_files(url_path):
    url_filename = url_path + '/api__urls.txt'

    if os.path.exists(url_path):
        pass
    else:
        os.makedirs(url_path, exist_ok=True)

    target_link = get_target_url(def_path)
    with open(url_filename, 'w') as file:
        file.write('\n'.join(target_link))
    command = f'wget -d -r -i {url_filename}'
    subprocess.run(command, shell=True)

# %%
download_deffile(def_path)
download_files(url_path)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading file: 24Mg-1H__XAB.def
# http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def
# [██████████████████████████████████████████████████] 100% Downloaded!
#
# Downloading file: 14N-16O__XABC.def
# http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.def
# [██████████████████████████████████████████████████] 100% Downloaded!
#
# All def files downloaded!
#
# The files which are failed to download:
#
# []
# 24Mg-1H__XAB.def
# 24Mg-1H__XAB.trans.bz2
#
# The number of downloading files for (24Mg)(1H) XAB :  4
# Download links:
# http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2
# http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2
# http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def
# http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf
# 14N-16O__XABC.trans.bz2
# 14N-16O__XABC.def
#
# The number of downloading files for (14N)(16O) XABC :  4
# Download links:
# http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2
# http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.states.bz2
# http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2
# http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2
# Setting --recursive (recursive) to 1
# Setting --input-file (input) to /home/jingxin/data/pyexocross/url/api__urls.txt
# DEBUG output created by Wget 1.21.1 on linux-gnu.
#
# Reading HSTS entries from /home/jingxin/.wget-hsts
# URI encoding = ‘UTF-8’
# URI content encoding = ‘UTF-8’
# Loaded /home/jingxin/data/pyexocross/url/api__urls.txt (size 504).
# Enqueuing http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2 at depth 0
# Queue count 1, maxcount 1.
# [IRI Enqueuing ‘http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2’ with ‘UTF-8’
# Dequeuing http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2 at depth 0
# Queue count 0, maxcount 1.
# Converted file name 'www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2' (UTF-8) -> 'www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2' (UTF-8)
# --2024-04-22 17:16:46--  http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2
# Resolving www.exomol.com (www.exomol.com)... 128.40.3.60
# Caching www.exomol.com => 128.40.3.60
# Connecting to www.exomol.com (www.exomol.com)|128.40.3.60|:80... connected.
# Created socket 3.
# Releasing 0x0000559a98839b10 (new refcount 1).
#
# ---request begin---
# GET /db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2 HTTP/1.1
# User-Agent: Wget/1.21.1
# Accept: */*
# Accept-Encoding: identity
# Host: www.exomol.com
# Connection: Keep-Alive
#
# ---request end---
# HTTP request sent, awaiting response...
# ---response begin---
# HTTP/1.1 301 Moved Permanently
# Date: Mon, 22 Apr 2024 16:16:46 GMT
# Server: Apache/2.4.57 (AlmaLinux) OpenSSL/3.0.7 mod_fcgid/2.3.9 mod_wsgi/4.7.1 Python/3.9
# Location: https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2
# Content-Length: 273
# Keep-Alive: timeout=5, max=100
# Connection: Keep-Alive
# Content-Type: text/html; charset=iso-8859-1
#
# ---response end---
# 301 Moved Permanently
# Registered socket 3 for persistent reuse.
# URI content encoding = ‘iso-8859-1’
# Location: https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2 [following]
# Skipping 273 bytes of body: [<!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>301 Moved Permanently</title>
# </head><body>
# <h1>Moved Permanently</h1>
# <p>The document has moved <a href="https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2">here</a>.</p>
# </body></html>
# ] done.
# URI content encoding = None
# Converted file name 'www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2' (UTF-8) -> 'www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2' (UTF-8)
# --2024-04-22 17:16:46--  https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2
# Certificates loaded: 354
# Found www.exomol.com in host_name_addresses_map (0x559a98839b10)
# Connecting to www.exomol.com (www.exomol.com)|128.40.3.60|:443... connected.
# Created socket 4.
# Releasing 0x0000559a98839b10 (new refcount 1).
#
# ---request begin---
# GET /db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2 HTTP/1.1
# User-Agent: Wget/1.21.1
# Accept: */*
# Accept-Encoding: identity
# Host: www.exomol.com
# Connection: Keep-Alive
#
# ---request end---
# HTTP request sent, awaiting response...
# ---response begin---
# HTTP/1.1 200 OK
# Date: Mon, 22 Apr 2024 16:16:46 GMT
# Server: Apache/2.4.57 (AlmaLinux) OpenSSL/3.0.7 mod_fcgid/2.3.9 mod_wsgi/4.7.1 Python/3.9
# Last-Modified: Wed, 22 Mar 2023 18:21:10 GMT
# ETag: "11608-5f781396f7180"
# Accept-Ranges: bytes
# Content-Length: 71176
# Keep-Alive: timeout=5, max=100
# Connection: Keep-Alive
# Content-Type: application/x-bzip2
#
# ---response end---
# 200 OK
# Disabling further reuse of socket 3.
# Closed fd 3
# Registered socket 4 for persistent reuse.
# Length: 71176 (70K) [application/x-bzip2]
# Saving to: ‘www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2’
#
#      0K .......... .......... .......... .......... .......... 71% 56.3M 0s
#     50K .......... .........                                  100%  473M=0.001s
#
# 2024-04-22 17:16:46 (74.8 MB/s) - ‘www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.states.bz2’ saved [71176/71176]
#
# Enqueuing http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2 at depth 0
# Queue count 1, maxcount 1.
# [IRI Enqueuing ‘http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2’ with ‘UTF-8’
# Dequeuing http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2 at depth 0
# Queue count 0, maxcount 1.
# Converted file name 'www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2' (UTF-8) -> 'www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2' (UTF-8)
# --2024-04-22 17:16:46--  http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2
# Found www.exomol.com in host_name_addresses_map (0x559a98839b10)
# Connecting to www.exomol.com (www.exomol.com)|128.40.3.60|:80... connected.
# Created socket 3.
# Releasing 0x0000559a98839b10 (new refcount 1).
#
# ---request begin---
# GET /db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2 HTTP/1.1
# User-Agent: Wget/1.21.1
# Accept: */*
# Accept-Encoding: identity
# Host: www.exomol.com
# Connection: Keep-Alive
#
# ---request end---
# HTTP request sent, awaiting response...
# ---response begin---
# HTTP/1.1 301 Moved Permanently
# Date: Mon, 22 Apr 2024 16:16:46 GMT
# Server: Apache/2.4.57 (AlmaLinux) OpenSSL/3.0.7 mod_fcgid/2.3.9 mod_wsgi/4.7.1 Python/3.9
# Location: https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2
# Content-Length: 272
# Keep-Alive: timeout=5, max=100
# Connection: Keep-Alive
# Content-Type: text/html; charset=iso-8859-1
#
# ---response end---
# 301 Moved Permanently
# Disabling further reuse of socket 4.
# Registered socket 3 for persistent reuse.
# URI content encoding = ‘iso-8859-1’
# Location: https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2 [following]
# Skipping 272 bytes of body: [<!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>301 Moved Permanently</title>
# </head><body>
# <h1>Moved Permanently</h1>
# <p>The document has moved <a href="https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2">here</a>.</p>
# </body></html>
# ] done.
# URI content encoding = None
# Converted file name 'www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2' (UTF-8) -> 'www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2' (UTF-8)
# --2024-04-22 17:16:46--  https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2
# Found www.exomol.com in host_name_addresses_map (0x559a98839b10)
# Connecting to www.exomol.com (www.exomol.com)|128.40.3.60|:443... connected.
# Created socket 4.
# Releasing 0x0000559a98839b10 (new refcount 1).
#
# ---request begin---
# GET /db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2 HTTP/1.1
# User-Agent: Wget/1.21.1
# Accept: */*
# Accept-Encoding: identity
# Host: www.exomol.com
# Connection: Keep-Alive
#
# ---request end---
# HTTP request sent, awaiting response...
# ---response begin---
# HTTP/1.1 200 OK
# Date: Mon, 22 Apr 2024 16:16:46 GMT
# Server: Apache/2.4.57 (AlmaLinux) OpenSSL/3.0.7 mod_fcgid/2.3.9 mod_wsgi/4.7.1 Python/3.9
# Last-Modified: Sat, 09 Apr 2022 09:16:49 GMT
# ETag: "ee4a8-5dc352bc10240"
# Accept-Ranges: bytes
# Content-Length: 976040
# Keep-Alive: timeout=5, max=100
# Connection: Keep-Alive
# Content-Type: application/x-bzip2
#
# ---response end---
# 200 OK
# Disabling further reuse of socket 3.
# Closed fd 3
# Registered socket 4 for persistent reuse.
# Length: 976040 (953K) [application/x-bzip2]
# Saving to: ‘www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2’
#
#      0K .......... .......... .......... .......... ..........  5%  125M 0s
#     50K .......... .......... .......... .......... .......... 10%  486M 0s
#    100K .......... .......... .......... .......... .......... 15%  153M 0s
#    150K .......... .......... .......... .......... .......... 20%  452M 0s
#    200K .......... .......... .......... .......... .......... 26%  309M 0s
#    250K .......... .......... .......... .......... .......... 31%  439M 0s
#    300K .......... .......... .......... .......... .......... 36%  357M 0s
#    350K .......... .......... .......... .......... .......... 41%  318M 0s
#    400K .......... .......... .......... .......... .......... 47%  298M 0s
#    450K .......... .......... .......... .......... .......... 52%  326M 0s
#    500K .......... .......... .......... .......... .......... 57%  467M 0s
#    550K .......... .......... .......... .......... .......... 62%  362M 0s
#    600K .......... .......... .......... .......... .......... 68%  320M 0s
#    650K .......... .......... .......... .......... .......... 73%  323M 0s
#    700K .......... .......... .......... .......... .......... 78%  308M 0s
#    750K .......... .......... .......... .......... .......... 83%  480M 0s
#    800K .......... .......... .......... .......... .......... 89%  340M 0s
#    850K .......... .......... .......... .......... .......... 94%  288M 0s
#    900K .......... .......... .......... .......... .......... 99%  313M 0s
#    950K ...                                                   100%  173M=0.003s
#
# 2024-04-22 17:16:46 (302 MB/s) - ‘www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.trans.bz2’ saved [976040/976040]
#
# Enqueuing http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def at depth 0
# Queue count 1, maxcount 1.
# [IRI Enqueuing ‘http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def’ with ‘UTF-8’
# Dequeuing http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def at depth 0
# Queue count 0, maxcount 1.
# Converted file name 'www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def' (UTF-8) -> 'www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def' (UTF-8)
# --2024-04-22 17:16:46--  http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def
# Found www.exomol.com in host_name_addresses_map (0x559a98839b10)
# Connecting to www.exomol.com (www.exomol.com)|128.40.3.60|:80... connected.
# Created socket 3.
# Releasing 0x0000559a98839b10 (new refcount 1).
#
# ---request begin---
# GET /db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def HTTP/1.1
# User-Agent: Wget/1.21.1
# Accept: */*
# Accept-Encoding: identity
# Host: www.exomol.com
# Connection: Keep-Alive
#
# ---request end---
# HTTP request sent, awaiting response...
# ---response begin---
# HTTP/1.1 301 Moved Permanently
# Date: Mon, 22 Apr 2024 16:16:46 GMT
# Server: Apache/2.4.57 (AlmaLinux) OpenSSL/3.0.7 mod_fcgid/2.3.9 mod_wsgi/4.7.1 Python/3.9
# Location: https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def
# Content-Length: 266
# Keep-Alive: timeout=5, max=100
# Connection: Keep-Alive
# Content-Type: text/html; charset=iso-8859-1
#
# ---response end---
# 301 Moved Permanently
# Disabling further reuse of socket 4.
# Registered socket 3 for persistent reuse.
# URI content encoding = ‘iso-8859-1’
# Location: https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def [following]
# Skipping 266 bytes of body: [<!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>301 Moved Permanently</title>
# </head><body>
# <h1>Moved Permanently</h1>
# <p>The document has moved <a href="https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def">here</a>.</p>
# </body></html>
# ] done.
# URI content encoding = None
# Converted file name 'www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def' (UTF-8) -> 'www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def' (UTF-8)
# --2024-04-22 17:16:46--  https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def
# Found www.exomol.com in host_name_addresses_map (0x559a98839b10)
# Connecting to www.exomol.com (www.exomol.com)|128.40.3.60|:443... connected.
# Created socket 4.
# Releasing 0x0000559a98839b10 (new refcount 1).
#
# ---request begin---
# GET /db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def HTTP/1.1
# User-Agent: Wget/1.21.1
# Accept: */*
# Accept-Encoding: identity
# Host: www.exomol.com
# Connection: Keep-Alive
#
# ---request end---
# HTTP request sent, awaiting response...
# ---response begin---
# HTTP/1.1 200 OK
# Date: Mon, 22 Apr 2024 16:16:46 GMT
# Server: Apache/2.4.57 (AlmaLinux) OpenSSL/3.0.7 mod_fcgid/2.3.9 mod_wsgi/4.7.1 Python/3.9
# Last-Modified: Mon, 18 Mar 2024 11:56:13 GMT
# ETag: "1d39-613ee0b53182a"
# Accept-Ranges: bytes
# Content-Length: 7481
# Keep-Alive: timeout=5, max=100
# Connection: Keep-Alive
#
# ---response end---
# 200 OK
# Disabling further reuse of socket 3.
# Closed fd 3
# Registered socket 4 for persistent reuse.
# Length: 7481 (7.3K)
# Saving to: ‘www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def’
#
#      0K .......                                               100%  312M=0s
#
# 2024-04-22 17:16:46 (312 MB/s) - ‘www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def’ saved [7481/7481]
#
# Deciding whether to enqueue "https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def".
# URI encoding = ‘UTF-8’
# Loading robots.txt; please ignore errors.
# Converted file name 'www.exomol.com/robots.txt' (UTF-8) -> 'www.exomol.com/robots.txt' (UTF-8)
# --2024-04-22 17:16:46--  https://www.exomol.com/robots.txt
# Reusing existing connection to www.exomol.com:443.
# Reusing fd 4.
#
# ---request begin---
# GET /robots.txt HTTP/1.1
# User-Agent: Wget/1.21.1
# Accept: */*
# Accept-Encoding: identity
# Host: www.exomol.com
# Connection: Keep-Alive
#
# ---request end---
# HTTP request sent, awaiting response...
# ---response begin---
# HTTP/1.1 200 OK
# Date: Mon, 22 Apr 2024 16:16:46 GMT
# Server: Apache/2.4.57 (AlmaLinux) OpenSSL/3.0.7 mod_fcgid/2.3.9 mod_wsgi/4.7.1 Python/3.9
# Content-Length: 25
# X-Frame-Options: DENY
# Vary: Cookie
# Keep-Alive: timeout=5, max=99
# Connection: Keep-Alive
# Content-Type: text/plain; charset=UTF-8
#
# ---response end---
# 200 OK
# URI content encoding = ‘UTF-8’
# Length: 25 [text/plain]
# Saving to: ‘www.exomol.com/robots.txt’
#
#      0K                                                       100%  108M=0s
#
# 2024-04-22 17:16:46 (108 MB/s) - ‘www.exomol.com/robots.txt’ saved [25/25]
#
# Rejecting path db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def because of rule ‘’.
# Not following https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def because robots.txt forbids it.
# Decided NOT to load it.
# Redirection "https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.def" failed the test.
# Enqueuing http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf at depth 0
# Queue count 1, maxcount 1.
# [IRI Enqueuing ‘http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf’ with ‘UTF-8’
# Dequeuing http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf at depth 0
# Queue count 0, maxcount 1.
# Converted file name 'www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf' (UTF-8) -> 'www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf' (UTF-8)
# --2024-04-22 17:16:46--  http://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf
# Found www.exomol.com in host_name_addresses_map (0x559a98839b10)
# Connecting to www.exomol.com (www.exomol.com)|128.40.3.60|:80... connected.
# Created socket 3.
# Releasing 0x0000559a98839b10 (new refcount 1).
#
# ---request begin---
# GET /db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf HTTP/1.1
# User-Agent: Wget/1.21.1
# Accept: */*
# Accept-Encoding: identity
# Host: www.exomol.com
# Connection: Keep-Alive
#
# ---request end---
# HTTP request sent, awaiting response...
# ---response begin---
# HTTP/1.1 301 Moved Permanently
# Date: Mon, 22 Apr 2024 16:16:46 GMT
# Server: Apache/2.4.57 (AlmaLinux) OpenSSL/3.0.7 mod_fcgid/2.3.9 mod_wsgi/4.7.1 Python/3.9
# Location: https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf
# Content-Length: 265
# Keep-Alive: timeout=5, max=100
# Connection: Keep-Alive
# Content-Type: text/html; charset=iso-8859-1
#
# ---response end---
# 301 Moved Permanently
# Disabling further reuse of socket 4.
# Registered socket 3 for persistent reuse.
# URI content encoding = ‘iso-8859-1’
# Location: https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf [following]
# Skipping 265 bytes of body: [<!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>301 Moved Permanently</title>
# </head><body>
# <h1>Moved Permanently</h1>
# <p>The document has moved <a href="https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf">here</a>.</p>
# </body></html>
# ] done.
# URI content encoding = None
# Converted file name 'www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf' (UTF-8) -> 'www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf' (UTF-8)
# --2024-04-22 17:16:46--  https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf
# Found www.exomol.com in host_name_addresses_map (0x559a98839b10)
# Connecting to www.exomol.com (www.exomol.com)|128.40.3.60|:443... connected.
# Created socket 4.
# Releasing 0x0000559a98839b10 (new refcount 1).
#
# ---request begin---
# GET /db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf HTTP/1.1
# User-Agent: Wget/1.21.1
# Accept: */*
# Accept-Encoding: identity
# Host: www.exomol.com
# Connection: Keep-Alive
#
# ---request end---
# HTTP request sent, awaiting response...
# ---response begin---
# HTTP/1.1 200 OK
# Date: Mon, 22 Apr 2024 16:16:46 GMT
# Server: Apache/2.4.57 (AlmaLinux) OpenSSL/3.0.7 mod_fcgid/2.3.9 mod_wsgi/4.7.1 Python/3.9
# Last-Modified: Mon, 22 Nov 2021 13:54:22 GMT
# ETag: "1e848-5d160f63fdf80"
# Accept-Ranges: bytes
# Content-Length: 125000
# Keep-Alive: timeout=5, max=100
# Connection: Keep-Alive
#
# ---response end---
# 200 OK
# Disabling further reuse of socket 3.
# Closed fd 3
# Registered socket 4 for persistent reuse.
# Length: 125000 (122K)
# Saving to: ‘www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf’
#
#      0K .......... .......... .......... .......... .......... 40% 6.85M 0s
#     50K .......... .......... .......... .......... .......... 81%  283M 0s
#    100K .......... .......... ..                              100%  267M=0.007s
#
# 2024-04-22 17:16:46 (16.1 MB/s) - ‘www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf’ saved [125000/125000]
#
# Deciding whether to enqueue "https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf".
# Rejecting path db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf because of rule ‘’.
# Not following https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf because robots.txt forbids it.
# Decided NOT to load it.
# Redirection "https://www.exomol.com/db/MgH/24Mg-1H/XAB/24Mg-1H__XAB.pf" failed the test.
# Enqueuing http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2 at depth 0
# Queue count 1, maxcount 1.
# [IRI Enqueuing ‘http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2’ with ‘UTF-8’
# Dequeuing http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2 at depth 0
# Queue count 0, maxcount 1.
# Converted file name 'www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2' (UTF-8) -> 'www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2' (UTF-8)
# --2024-04-22 17:16:46--  http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2
# Found www.exomol.com in host_name_addresses_map (0x559a98839b10)
# Connecting to www.exomol.com (www.exomol.com)|128.40.3.60|:80... connected.
# Created socket 3.
# Releasing 0x0000559a98839b10 (new refcount 1).
#
# ---request begin---
# GET /db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2 HTTP/1.1
# User-Agent: Wget/1.21.1
# Accept: */*
# Accept-Encoding: identity
# Host: www.exomol.com
# Connection: Keep-Alive
#
# ---request end---
# HTTP request sent, awaiting response...
# ---response begin---
# HTTP/1.1 301 Moved Permanently
# Date: Mon, 22 Apr 2024 16:16:46 GMT
# Server: Apache/2.4.57 (AlmaLinux) OpenSSL/3.0.7 mod_fcgid/2.3.9 mod_wsgi/4.7.1 Python/3.9
# Location: https://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2
# Content-Length: 273
# Keep-Alive: timeout=5, max=100
# Connection: Keep-Alive
# Content-Type: text/html; charset=iso-8859-1
#
# ---response end---
# 301 Moved Permanently
# Disabling further reuse of socket 4.
# Registered socket 3 for persistent reuse.
# URI content encoding = ‘iso-8859-1’
# Location: https://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2 [following]
# Skipping 273 bytes of body: [<!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>301 Moved Permanently</title>
# </head><body>
# <h1>Moved Permanently</h1>
# <p>The document has moved <a href="https://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz
www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.states.bz2">here</a>.</p>
# </body></html>
# ] done.
# URI content encoding = None
# Converted file name 'www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.states.bz2' (UTF-8) -> 'www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.states.bz2' (UTF-8)
# --2024-04-22 17:16:47--  https://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.states.bz2
# Found www.exomol.com in host_name_addresses_map (0x559a98839b10)
# Connecting to www.exomol.com (www.exomol.com)|128.40.3.60|:443... connected.
# Created socket 4.
# Releasing 0x0000559a98839b10 (new refcount 1).
#
# ---request begin---
# GET /db/NO/14N-16O/XABC/14N-16O__XABC.states.bz2 HTTP/1.1
# User-Agent: Wget/1.21.1
# Accept: */*
# Accept-Encoding: identity
# Host: www.exomol.com
# Connection: Keep-Alive
#
# ---request end---
# HTTP request sent, awaiting response...
# ---response begin---
# HTTP/1.1 200 OK
# Date: Mon, 22 Apr 2024 16:16:47 GMT
# Server: Apache/2.4.57 (AlmaLinux) OpenSSL/3.0.7 mod_fcgid/2.3.9 mod_wsgi/4.7.1 Python/3.9
# Last-Modified: Tue, 12 Mar 2024 22:25:54 GMT
# ETag: "a3be5-6137e242d0080"
# Accept-Ranges: bytes
# Content-Length: 670693
# Keep-Alive: timeout=5, max=100
# Connection: Keep-Alive
# Content-Type: application/x-bzip2
#
# ---response end---
# 200 OK
# Disabling further reuse of socket 3.
# Closed fd 3
# Registered socket 4 for persistent reuse.
# Length: 670693 (655K) [application/x-bzip2]
# Saving to: ‘www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.states.bz2’
#
#      0K .......... .......... .......... .......... ..........  7% 90.9M 0s
#     50K .......... .......... .......... .......... .......... 15%  331M 0s
#    100K .......... .......... .......... .......... .......... 22%  237M 0s
#    150K .......... .......... .......... .......... .......... 30%  507M 0s
#    200K .......... .......... .......... .......... .......... 38%  288M 0s
#    250K .......... .......... .......... .......... .......... 45%  346M 0s
#    300K .......... .......... .......... .......... .......... 53%  546M 0s
#    350K .......... .......... .......... .......... .......... 61%  314M 0s
#    400K .......... .......... .......... .......... .......... 68%  394M 0s
#    450K .......... .......... .......... .......... .......... 76%  449M 0s
#    500K .......... .......... .......... .......... .......... 83%  302M 0s
#    550K .......... .......... .......... .......... .......... 91%  505M 0s
#    600K .......... .......... .......... .......... .......... 99%  422M 0s
#    650K ....                                                  100% 9.26T=0.002s
#
# 2024-04-22 17:16:47 (298 MB/s) - ‘www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.states.bz2’ saved [670693/670693]
#
# Enqueuing http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2 at depth 0
# Queue count 1, maxcount 1.
# [IRI Enqueuing ‘http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2’ with ‘UTF-8’
# Dequeuing http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2 at depth 0
# Queue count 0, maxcount 1.
# Already downloaded "http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2", reusing it from "www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2".
# Enqueuing http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2 at depth 0
# Queue count 1, maxcount 1.
# [IRI Enqueuing ‘http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2’ with ‘UTF-8’
# Dequeuing http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2 at depth 0
# Queue count 0, maxcount 1.
# Already downloaded "http://www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2", reusing it from "www.exomol.com/db/NO/14N-16O/XABC/14N-16O__XABC.trans.bz2".
# FINISHED --2024-04-22 17:16:47--
# Total wall clock time: 0.6s
# Downloaded: 7 files, 54M in 0.2s (321 MB/s)
